# %% [markdown]
# ### Task 1: Write Sales Records to a File

# %%
sales = [1200, 450, 980, 1500, 3000]

# %%
with open("sales_data.txt", "w") as file:
    for sale in sales:
        file.write(str(sale) + "\n")

# %%
with open("sales_data.txt", "r") as file:
    print(file.read())

# %% [markdown]
# ### Task 2: Read File in Different Ways

# %%
with open("sales_data.txt", "r") as file:
    print("Using read():")
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open("sales_data.txt", "r") as file:
#       2     print("Using read():")
#       3     print(file.read())
#
# File c:\Users\yasht\Desktop\New folder (2)\GenAi\python\venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sales_data.txt'

# %%
with open("sales_data.txt", "r") as file:
    print("Using readline():")
    print(file.readline().strip())

# %%
with open("sales_data.txt", "r") as file:
    lines = file.readlines()
    sales_list = [int(line.strip()) for line in lines]

# %%
print("Sales as integers:", sales_list)

# %% [markdown]
# ### Task 3: Append New Sales

# %%
new_sales = [5000, 2500, 1700]

# %%
with open("sales_data.txt", "a") as file:
    for sale in new_sales:
        file.write(str(sale) + "\n")

# %%
with open("sales_data.txt", "r") as file:
    all_lines = file.readlines()
    print("Updated File Contents:")
    for line in all_lines:
        print(line.strip())

# %%
print("Total number of lines:", len(all_lines))

# %% [markdown]
# ### Task 4: Generate Summary Report

# %%
with open("sales_data.txt", "r") as file:
    sales = [int(line.strip()) for line in file.readlines()]

# %%
total_sales = sum(sales)
highest_sale = max(sales)
lowest_sale = min(sales)
average_sale = total_sales / len(sales)

# %%
print("Total Sales:", total_sales)
print("Highest Sale:", highest_sale)
print("Lowest Sale:", lowest_sale)
print("Average Sale:", average_sale)

# %% [markdown]
# ### Task 5: Create Product Info File (User Input)

# %%
products = []

# %%
for i in range(3):
    name = input("Enter product name: ")
    price = input("Enter product price: ")
    products.append(f"{name} | {price}")

# %%
with open("products.txt", "w") as file:
    for product in products:
        file.write(product + "\n")

# %%
with open("products.txt", "r") as file:
    print("Product List:")
    for line in file:
        print(line.strip())

# %% [markdown]
# ### Task 6: Read File Safely

# %%
import os

# %%
filename = input("Enter filename to open: ")

# %%
if os.path.exists(filename):
    with open(filename, "r") as file:
        print(file.read())
else:
    print("File not found. Please check the filename.")

# %% [markdown]
# ### Task 7: Mini Project – Export Discounted Prices

# %%
prices = {
    "Mouse": 500,
    "Keyboard": 800,
    "Monitor": 7000,
    "Pendrive": 400,
    "Camera": 5000
}

# %%
discount = float(input("Enter discount percentage: "))

# %%
with open("discount_report.txt", "w") as file:
    file.write("Product | Original Price | Discounted Price\n")

    total_discounted = 0

    for product, price in prices.items():
        discounted_price = price - (price * discount / 100)
        total_discounted += discounted_price
        file.write(f"{product} | {price} | {discounted_price}\n")

    average_discounted = total_discounted / len(prices)

    file.write("\n")
    file.write(f"Total Items: {len(prices)}\n")
    file.write(f"Average Discounted Price: {average_discounted}\n")

# %%
with open("discount_report.txt", "r") as file:
    print(file.read())
